# %%
import pandas as pd
data = pd.read_csv(r'C:\Users\hanao\Downloads\headline-hoax-detector\ds-role\dataset\raw\dewan_pers.csv')

# %%
data.head()
# Out:
#           nama_media                          jenis_media penanggung_jawab  \
# 0                NaN  Cetak\r\nRadio\r\nTelevisi\r\nSiber              NaN
# 1    Jabungtoday.com                                Siber    Hendry Nursal
# 2          Akurat.co                                Siber      Aldi Gultom
# 3  bentengsumbar.com                                Siber      Zamri Yahya
# 4   Tribun Pekanbaru                                Cetak     Erwin Ardian
#
#   pemimpin_redaksi             badan_hukum        provinsi  \
# 0              NaN                     NaN             NaN
# 1    Hendry Nursal      Media Putra Jabung           Jambi
# 2      Aldi Gultom     Akurat Sentra Media     DKI Jakarta
# 3      Zamri Yahya  Benteng Sumbar Persada  Sumatera Barat
# 4     Erwin Ardian      Riau Media Grafika            Riau
#
#                                               alamat          telp  \
# 0                                                NaN           NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2640 entries, 0 to 2639
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   nama_media        2400 non-null   object
#  1   jenis_media       2640 non-null   object
#  2   penanggung_jawab  1766 non-null   object
#  3   pemimpin_redaksi  1766 non-null   object
#  4   badan_hukum       2396 non-null   object
#  5   provinsi          2395 non-null   object
#  6   alamat            2373 non-null   object
#  7   telp              1898 non-null   object
#  8   email             1849 non-null   object
#  9   website           1711 non-null   object
#  10  status            2400 non-null   object
#  11  tanggal           2400 non-null   object
# dtypes: object(12)
# memory usage: 247.6+ KB

# %%
data['jenis_media'].unique()
# Out:
# array(['Cetak\r\nRadio\r\nTelevisi\r\nSiber', 'Siber', 'Cetak',
#        'Televisi', 'Radio'], dtype=object)

# %%
data = data[data['jenis_media'] == 'Siber']
data.head()
# Out:
#            nama_media jenis_media penanggung_jawab pemimpin_redaksi  \
# 1     Jabungtoday.com       Siber    Hendry Nursal    Hendry Nursal
# 2           Akurat.co       Siber      Aldi Gultom      Aldi Gultom
# 3   bentengsumbar.com       Siber      Zamri Yahya      Zamri Yahya
# 5          niaga.asia       Siber       Intoniswan       Intoniswan
# 6  mediaindonesia.com       Siber      Abdul Kohar      Abdul Kohar
#
#                 badan_hukum          provinsi  \
# 1        Media Putra Jabung             Jambi
# 2       Akurat Sentra Media       DKI Jakarta
# 3    Benteng Sumbar Persada    Sumatera Barat
# 5  Kaltim prima multi media  Kalimantan Timur
# 6   Citra Medianusa Purnama       DKI Jakarta
#
#                                               alamat          telp  \
# 1  Jl.Ternate, Lrg.Puspon, RT 03 No 49 Simpang Su...  081313024411
# 2  Jl. Tentara Pelajar Rukan Permata Senayan Blok...   02157941110
# 3  Jalan Piai Tangah RT.001/RW.001 Kelurahan Piai...    0751779490
# ...

# %%
data.shape
# Out:
# (1295, 12)

# %%
data['status'].unique()
# Out:
# array(['Terverifikasi Administratif dan Faktual',
#        'Terverifikasi Administratif',
#        'Terverifikasi Administrasi dan Faktual',
#        'Terverifikasi Administrasi'], dtype=object)

# %%
data = data[data['status'] == 'Terverifikasi Administratif dan Faktual']
data.head()
# Out:
#            nama_media jenis_media penanggung_jawab pemimpin_redaksi  \
# 1     Jabungtoday.com       Siber    Hendry Nursal    Hendry Nursal
# 2           Akurat.co       Siber      Aldi Gultom      Aldi Gultom
# 3   bentengsumbar.com       Siber      Zamri Yahya      Zamri Yahya
# 5          niaga.asia       Siber       Intoniswan       Intoniswan
# 6  mediaindonesia.com       Siber      Abdul Kohar      Abdul Kohar
#
#                 badan_hukum          provinsi  \
# 1        Media Putra Jabung             Jambi
# 2       Akurat Sentra Media       DKI Jakarta
# 3    Benteng Sumbar Persada    Sumatera Barat
# 5  Kaltim prima multi media  Kalimantan Timur
# 6   Citra Medianusa Purnama       DKI Jakarta
#
#                                               alamat          telp  \
# 1  Jl.Ternate, Lrg.Puspon, RT 03 No 49 Simpang Su...  081313024411
# 2  Jl. Tentara Pelajar Rukan Permata Senayan Blok...   02157941110
# 3  Jalan Piai Tangah RT.001/RW.001 Kelurahan Piai...    0751779490
# ...

# %%
data.shape
# Out:
# (933, 12)

# %%
data = data[['nama_media', 'website']]
data.head()
# Out:
#            nama_media                         website
# 1     Jabungtoday.com        https://jabungtoday.com/
# 2           Akurat.co              https://akurat.co/
# 3   bentengsumbar.com  https://www.bentengsumbar.com/
# 5          niaga.asia         https://www.niaga.asia/
# 6  mediaindonesia.com          www.mediaindonesia.com

# %%
data.isnull().sum()
# Out:
# nama_media     0
# website       58
# dtype: int64

# %%
data = data.dropna()
print(f"Shape after dropping NaN values: {data.shape}")
# Out:
# Shape after dropping NaN values: (875, 2)

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.drop_duplicates()
print(f"Shape after dropping duplicate: {data.shape}")
# Out:
# Shape after dropping duplicate: (875, 2)

# %%
# Simpan hanya kolom yang diperlukan untuk training
data.to_csv(r'C:\Users\hanao\Downloads\headline-hoax-detector\ds-role\dataset\final\final-pers.csv', index=False)
print("Data berhasil disimpan!")
# Out:
# Data berhasil disimpan!
